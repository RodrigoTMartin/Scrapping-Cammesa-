# %% [markdown]
# ## Scrape results of UNMSM's admission exam (2024-I)
# The exam comprises 100 multiple-choice questions —ranging from mathematics to social sciences, humanities, physics, chemistry, and biology— and spans a duration of 3 hours. Each correct answer carries 20 points, while an incorrect response deducts 1.125 points, and blank answers hold no point value. The maximum (and nearly impossible) score is 2,000 points. The objective of this code is to scrape the results of the 2024-I UNMSM's exam.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Base URL for the subpages
base_url = "https://admision.unmsm.edu.pe/Website20241/A/"

# Career codes and keep string all variables (see Excel file in raw folder)
career_codes = [
 '011', '012', '013', '015', '041', '042', '043', '051', '081', '181', '182', '071',
 '101', '102', '103', '131', '141', '142', '144', '145', '072', '073', '132', '162',
 '163', '165', '166', '167', '168', '171', '172', '173', '191', '192', '193', '194',
 '201', '202', '091', '092', '093', '111', '112', '113', '121', '122', '123', '022',
 '023', '031', '033', '034', '035', '036', '037', '038', '039', '062', '151', '152',
 '153', '154', '155', '157', '0911', '0912', '0921', '0932', '0931', '0922', '1131',
 '203', '1111', '0611', '0612', '0613', '1121', '114', '1141', '0141', '0143', '0142', '0144'
]

# %%
# Initialize an empty list to store all the data
all_data = []

# Iterate over each code and scrape the corresponding page
for code in career_codes:
    # Construct the URL for the subpage
    subpage_url = f"{base_url}{str(code).zfill(3)}/0.html"

    try:
        # Fetch the content of the subpage
        response = requests.get(subpage_url)
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the table containing the results
        table = soup.find('table')

        if table:
            # Extract rows from the table
            rows = table.find_all('tr')
            print(f"Table from {subpage_url}:")

            # Iterate over each row and extract the data
            for row in rows[1:]:  # Skipping the header row
                cols = row.find_all('td')
                if len(cols) >= 7: #7 variables in this Exam 2023-II
                    # Extracting the required variables
                    data = {
                        'idcode': cols[0].text.strip(),
                        'fullname': cols[1].text.strip(),
                        'career': cols[2].text.strip(),
                        'examscore': cols[3].text.strip(),
                        'ranking': cols[4].text.strip(),
                        'status': cols[5].text.strip(),
                        'careercode': str(code),
                        'secondcareer': cols[6].text.strip(),
                        'exam': '2024-I'
                    }
                    all_data.append(data)
    except Exception as e:
        print(f"An error occurred while processing code {code}: {e}")
        break

# Convert the data to a pandas DataFrame
results_df = pd.DataFrame(all_data)

# Export the DataFrame to a CSV file
results_df.to_csv('../data/raw/scraping_results_unmsm.csv', index=False)

results_df.sample(20)
# Out:
# Table from https://admision.unmsm.edu.pe/Website20241/A/011/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/012/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/013/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/015/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/041/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/042/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/043/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/051/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/081/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/181/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/182/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/071/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/101/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/102/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/103/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/131/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/141/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/142/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/144/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/145/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/072/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/073/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/132/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/162/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/163/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/165/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/166/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/167/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/168/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/171/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/172/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/173/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/191/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/192/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/193/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/194/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/201/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/202/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/091/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/092/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/093/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/111/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/112/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/113/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/121/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/122/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/123/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/022/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/023/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/031/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/033/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/034/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/035/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/036/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/037/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/038/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/039/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/062/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/151/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/152/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/153/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/154/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/155/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/157/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0911/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0912/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0921/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0932/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0931/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0922/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/1131/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/203/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/1111/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0611/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0612/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0613/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/1121/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/114/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/1141/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0141/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0143/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0142/0.html:
# Table from https://admision.unmsm.edu.pe/Website20241/A/0144/0.html:
#        idcode                            fullname  \
# 7912   156634       SANCHEZ SARMIENTO, ANDRE ABEL
# 6290   110336      TUCTO ANTUNEZ, JOSEPH WILLIAMS
# 15735  274046        BECERRA CHOMBO, LUIS ALFREDO
# 23733  729533        GONZALES SILVA, SAARA INDIRA
# 12458  270753          PAIMA PEZO, GILARY TATIANA
# 9837   150240  MATURRANO SORIA, CAROLINE GABRIELA
# 12767  275668       VARAS FLORES, JOSE MARIA CRUZ
# 3649   881579    PERALTA GARIBAY, YAMELIN DANIELA
# 21244  587507         TOSCANO TAPIA, ANGIE ANABEL
# 11769  296555        ACOSTA HUAMÁN, DAYANA NICOLE
# 11691  221916            YANAC ROSAS, ELVIS KEVIN
# 2207   850370      HEREDIA CALLE, CAMILA GABRIELA
# 16200  277480          GAMARRA PONCE, JERRY JARÉN
# 9012   199582    MEZA VELASQUEZ, JAQUELINE GLORIA
# 6830   181731    TORRES PALACIOS, MARICIELO LISET
# 24656  748119        PEREZ CORTEZ, HERNAN GONZALO
# 23179  722099        CCOYURE RIMACHE, LIZ SOLEDAD
# 22442  575327          CRUZ SANCHEZ, MAYRA ELISSA
# 4233   854632       ROJAS ARONI, VALERIA STEFANIA
# 6319   160913    VILCATOMA AYBAR, MARIA CRISTHINA
#
#                                                   career  examscore ranking  \
# 7912                                MEDICINA VETERINARIA   489.1250
# 6290                                          ENFERMERÍA   584.6250
# 15735                             INGENIERÍA DE SISTEMAS   626.8750
# 23733                                            DERECHO   535.2500
# 12458                                   INGENIERÍA CIVIL   474.7500
# 9837    PSICOLOGÍA ORGANIZACIONAL Y DE LA GESTIÓN HUMANA   847.1250
# 12767                                   INGENIERÍA CIVIL   350.2500
# 3649                                     MEDICINA HUMANA   609.6250
# 21244  AUDITORÍA EMPRESARIAL Y DEL SECTOR PÚBLICO - LIMA   861.5000
# 11769                                   INGENIERÍA CIVIL  1049.3750
# 11691                                INGENIERÍA DE MINAS   267.7500
# 2207                                     MEDICINA HUMANA   457.8750
# 16200                             INGENIERÍA DE SISTEMAS   529.6250
# 9012                                          PSICOLOGÍA   493.8750
# 6830                               FARMACIA Y BIOQUÍMICA   422.8750
# 24656                                            DERECHO   820.3750
# 23179                                            DERECHO   902.6250
# 22442                             ECONOMÍA INTERNACIONAL   610.5000
# 4233                                     MEDICINA HUMANA   598.1250
# 6319                                          ENFERMERÍA   228.2500
#
#       status careercode secondcareer    exam
# 7912                081               2024-I
# 6290                013               2024-I
# 15735               201               2024-I
# 23733               022               2024-I
# 12458               167               2024-I
# 9837                182               2024-I
# 12767               167               2024-I
# 3649                011               2024-I
# 21244               113               2024-I
# 11769               167               2024-I
# 11691               165               2024-I
# 2207                011               2024-I
# 16200               201               2024-I
# 9012                181               2024-I
# 6830                041               2024-I
# 24656               022               2024-I
# 23179               022               2024-I
# 22442               123               2024-I
# 4233                011               2024-I
# 6319                013               2024-I
